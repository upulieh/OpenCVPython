# %%
print('Hello')
# Out:
# Hello

# %%
import cv2
from matplotlib import pyplot as plt

im=cv2.imread(r'C:\Users\iresh\source\repos\Winforms\IUPLabs\test.jpg',1)
im2=im[:,:,::-1]
plt.imshow(im2)
plt.show()

# %%
import cv2

img=cv2.imread(r'C:\\Users\\iresh\\source\\repos\\Winforms\\IUPLabs\\test.jpg',0)

cv2.imshow("test1",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

img=cv2.imread(r'C:\\Users\\iresh\\source\\repos\\Winforms\\IUPLabs\\test.jpg',1)

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

cv2.imshow("test2",img)

cv2.imshow("test3",gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

img=cv2.imread(r'C:\\Users\\iresh\\source\\repos\\Winforms\\IUPLabs\\test.jpg',0)

ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

cv2.imshow("test4",img)

cv2.imshow("test5",thresh1)

cv2.waitKey(0)
cv2.destroyAllWindows()
